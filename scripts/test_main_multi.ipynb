# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd()
if not (PROJECT_ROOT / "training").exists():
    PROJECT_ROOT = PROJECT_ROOT.parent
sys.path.insert(0, str(PROJECT_ROOT))

# %%
from testing.analyze import Analysis
from testing.model_test import MetricsLoader
# Out:
# /Users/connorott/PycharmProjects/bioml/.venv/lib/python3.12/site-packages/keras/src/export/tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):

# %%
run_dir = PROJECT_ROOT / "experiments" / "rm_out_norm1"
trial_names = None #["trial_0000", "trial_0003", "trial_0006"]
epoch = -1

# %%
train_trials, trial_names = MetricsLoader.load_run(run_dir, "train", trial_names=trial_names)
val_trials, _ = MetricsLoader.load_run(run_dir, "val", trial_names=trial_names)
analysis = Analysis(train_trials, val_trials, trial_names=trial_names)

# %%
analysis.plot_epoch_scores()
#analysis.plot_logit_separation(epoch=epoch)
# Out:
# (<Figure size 1200x900 with 4 Axes>,
#  array([<Axes: ylabel='Loss'>, <Axes: ylabel='MCC'>, <Axes: ylabel='F1'>,
#         <Axes: xlabel='Epoch', ylabel='AUPRC'>], dtype=object))

# %%
analysis.plot_logit_separation(epoch=0)
# Out:
# (<Figure size 1200x3200 with 16 Axes>,
#  array([[<Axes: title={'center': 'Train Logit Separation'}, xlabel='Logits', ylabel='trial_0000'>,
#          <Axes: title={'center': 'Validation Logit Separation'}, xlabel='Logits', ylabel='Density'>],
#         [<Axes: xlabel='Logits', ylabel='trial_0001'>,
#          <Axes: xlabel='Logits', ylabel='Density'>],
#         [<Axes: xlabel='Logits', ylabel='trial_0002'>,
#          <Axes: xlabel='Logits', ylabel='Density'>],
#         [<Axes: xlabel='Logits', ylabel='trial_0003'>,
#          <Axes: xlabel='Logits', ylabel='Density'>],
#         [<Axes: xlabel='Logits', ylabel='trial_0004'>,
#          <Axes: xlabel='Logits', ylabel='Density'>],
#         [<Axes: xlabel='Logits', ylabel='trial_0005'>,
#          <Axes: xlabel='Logits', ylabel='Density'>],
#         [<Axes: xlabel='Logits', ylabel='trial_0006'>,
#          <Axes: xlabel='Logits', ylabel='Density'>],
#         [<Axes: xlabel='Logits', ylabel='trial_0007'>,
# ...

# %%
analysis.plot_logit_separation(epoch=2)
# Out:
# (<Figure size 1200x3200 with 16 Axes>,
#  array([[<Axes: title={'center': 'Train Logit Separation'}, xlabel='Logits', ylabel='trial_0000'>,
#          <Axes: title={'center': 'Validation Logit Separation'}, xlabel='Logits', ylabel='Density'>],
#         [<Axes: xlabel='Logits', ylabel='trial_0001'>,
#          <Axes: xlabel='Logits', ylabel='Density'>],
#         [<Axes: xlabel='Logits', ylabel='trial_0002'>,
#          <Axes: xlabel='Logits', ylabel='Density'>],
#         [<Axes: xlabel='Logits', ylabel='trial_0003'>,
#          <Axes: xlabel='Logits', ylabel='Density'>],
#         [<Axes: xlabel='Logits', ylabel='trial_0004'>,
#          <Axes: xlabel='Logits', ylabel='Density'>],
#         [<Axes: xlabel='Logits', ylabel='trial_0005'>,
#          <Axes: xlabel='Logits', ylabel='Density'>],
#         [<Axes: xlabel='Logits', ylabel='trial_0006'>,
#          <Axes: xlabel='Logits', ylabel='Density'>],
#         [<Axes: xlabel='Logits', ylabel='trial_0007'>,
# ...

# %%
analysis.plot_logit_separation(epoch=8)
# Out:
# (<Figure size 1200x3200 with 16 Axes>,
#  array([[<Axes: title={'center': 'Train Logit Separation'}, xlabel='Logits', ylabel='trial_0000'>,
#          <Axes: title={'center': 'Validation Logit Separation'}, xlabel='Logits', ylabel='Density'>],
#         [<Axes: xlabel='Logits', ylabel='trial_0001'>,
#          <Axes: xlabel='Logits', ylabel='Density'>],
#         [<Axes: xlabel='Logits', ylabel='trial_0002'>,
#          <Axes: xlabel='Logits', ylabel='Density'>],
#         [<Axes: xlabel='Logits', ylabel='trial_0003'>,
#          <Axes: xlabel='Logits', ylabel='Density'>],
#         [<Axes: xlabel='Logits', ylabel='trial_0004'>,
#          <Axes: xlabel='Logits', ylabel='Density'>],
#         [<Axes: xlabel='Logits', ylabel='trial_0005'>,
#          <Axes: xlabel='Logits', ylabel='Density'>],
#         [<Axes: xlabel='Logits', ylabel='trial_0006'>,
#          <Axes: xlabel='Logits', ylabel='Density'>],
#         [<Axes: xlabel='Logits', ylabel='trial_0007'>,
# ...
